# %% [markdown]
# Load model

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations
import seaborn as sns
import matplotlib.pyplot as plt

# Dataloading
df = pd.read_csv("../../results/NLP_data_advice_fulltext.csv")
docs = list(df["text"])
docs = [doc.replace('\xa0', '') for doc in docs]
classes = list(df["gen"])

# Model loading
embedding_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2", use_auth_token=False)
topic_model = BERTopic.load("../../results/NLP/BERTopic_model", embedding_model=embedding_model)
topics = list(topic_model.get_document_info(docs)["Topic"])

# %% [markdown]
# Fig 3C

# %%
topic_model.visualize_hierarchy(top_n_topics=6)

# %% [markdown]
# SI X

# %%
topic_model.visualize_heatmap(use_ctfidf=True)

# %%
topic_model.visualize_barchart(top_n_topics=9)
